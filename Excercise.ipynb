# %% [markdown]
# # Dependencies

# %%
import pandas as pd

# %% [markdown]
# # Targets:
#
# 1. Fix data types of the dataset [dtypes]
# 2. Fix column names to not have spaces and have short names.
#     2.1 Also, prepare data dictionary for new column names.
# 3. Create better features [by combining some columns]
# 4. Check co-relation and highlight highly correlated variables
# 5. Remove correlated variables
# 6. Get Count, Average, min and max for each month by each year of all numerical fields.
# 7. ***[Advanced step]*** Based on all above steps compute relative change:
#     7.1 Monthly
#     7.2 Yearly
#
# *** Also, implement everything else that you find important for this analysis***

# %% [markdown]
# # Resources
#
# This is a good introductory python repository for Exploratory Data Analysis.
#
# <a href="https://github.com/cmawer/pycon-2017-eda-tutorial/tree/master/notebooks"> EDA Tutorial</a>

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv('data.csv')
ncol = df.shape[1]
# changed the option of head to display all columns
pd.set_option('display.max_columns', ncol)

# if dataset is not very large then head else
df.head()

# df.sample(5)
# Out:
#    Unnamed: 0  Year  Month  \
# 0           0  2017      7
# 1           1  2017      6
# 2           2  2017      5
# 3           3  2017      4
# 4           4  2017      3
#
#   Net generation other renewables (total)  (thousand megawatthours)  \
# 0                                           303.5966
# 1                                          279.92249
# 2                                          274.68961
# 3                                          268.04368
# 4                                          272.50137
#
#    Average retail price of electricity (cents per KWH)  \
# 0                                              12.53
# 1                                              12.79
# 2                                              12.73
# 3                                              12.71
# 4                                              12.82
#
#    Retail sales of electricity (million kilowatthours)  \
# 0                                         3429.51828
# 1                                         2727.88024
# 2                                         2262.40423
# 3                                         2044.88955
# 4                                         2127.99069
#
#    Revenue from retail sales of electricity total(million dollars)  \
# 0                                          878.76993
# 1                                          766.67053
# 2                                          681.01506
# 3                                          623.23465
# 4                                          643.88836
#
#    Revenue from retail sales of electricity residential (million dollars)  \
# 0                                          429.58206
# 1                                          348.87341
# 2                                          287.89061
# 3                                          259.84629
# 4                                          272.88091
#
#   Total consumption coal (thousand tons)  \
# 0                               1858.693
# 1                               1489.063
# 2                               1310.503
# 3                                1130.11
# 4                               1271.181
#
#   Total consumption petroleum liquid (thousand barrels)  \
# 0                                              3.938
# 1                                              2.741
# 2                                              4.459
# 3                                              3.524
# 4                                              5.062
#
#   Total consumption  natural gas (thousand Mcf)           unqid    kt_avg  \
# 0                                     42893.952  2017_7_Alabama  0.558278
# 1                                     33357.656  2017_6_Alabama  0.470984
# 2                                     30762.064  2017_5_Alabama  0.536478
# 3                                     29599.447  2017_4_Alabama  0.585944
# 4                                     30229.111  2017_3_Alabama  0.530641
#
#      T2M_avg  WS10M_avg    State  kt_max  T2M_max  WS10M_max  kt_min  T2M_min  \
# 0  27.427392   1.380161  Alabama    0.71    30.42       3.20    0.08    24.62
# 1  24.293833   1.712028  Alabama    0.71    27.62       4.20    0.06    19.44
# 2  21.701156   2.037876  Alabama    0.75    27.64       4.59    0.10     9.62
# 3  19.618250   2.277944  Alabama    0.77    26.37       5.69    0.04     9.62
# 4  13.752742   2.474113  Alabama    0.76    22.85       4.59    0.04     0.22
#
#    WS10M_min for wind , Power = 1.93 * V^3 * R^2 * Cp , in watts  \
# 0       0.43  Cp is max power coefficient , varies from 0.25...
# 1       0.79                r is radius of swept area in meters
# 2       0.85                           V is wind speed  in m/s
# 3       0.91                                                NaN
# 4       1.11                           Note : for other columns
#
#           for solar , 1367 * kt * r ^ 2 * efficiency  \
# 0                        r is length of solar array
# 1   efficiency , varies from 14 to 24 % , max of ...
# 2                                         kt we have
# 3                                                NaN
# 4                                                NaN
#
#    total_renewable_policy_count  Wind_policy_count  \
# 0                            37                  5
# 1                            37                  5
# 2                            37                  5
# 3                            37                  5
# 4                            37                  5
#
#    Solar_photovoltaic_policy_count
# 0                                7
# 1                                7
# 2                                7
# 3                                7
# 4                                7

# %%
# Getting index for the columns in dataframe

columnnames = df.columns
for i in range(len(columnnames)):
    print('index: {} \tcolumn name:  {}'.format(i, columnnames[i]))
# Out:
# index: 0 	column name:  Unnamed: 0
# index: 1 	column name:  Year
# index: 2 	column name:  Month
# index: 3 	column name:  Net generation other renewables (total)  (thousand megawatthours)
# index: 4 	column name:  Average retail price of electricity (cents per KWH)
# index: 5 	column name:  Retail sales of electricity (million kilowatthours)
# index: 6 	column name:  Revenue from retail sales of electricity total(million dollars)
# index: 7 	column name:  Revenue from retail sales of electricity residential (million dollars)
# index: 8 	column name:  Total consumption coal (thousand tons)
# index: 9 	column name:  Total consumption petroleum liquid (thousand barrels)
# index: 10 	column name:  Total consumption  natural gas (thousand Mcf)
# index: 11 	column name:  unqid
# index: 12 	column name:  kt_avg
# index: 13 	column name:  T2M_avg
# index: 14 	column name:  WS10M_avg
# index: 15 	column name:  State
# index: 16 	column name:  kt_max
# index: 17 	column name:  T2M_max
# index: 18 	column name:  WS10M_max
# index: 19 	column name:  kt_min
# index: 20 	column name:  T2M_min
# index: 21 	column name:  WS10M_min
# index: 22 	column name:  for wind , Power = 1.93 * V^3 * R^2 * Cp , in watts
# index: 23 	column name:  for solar , 1367 * kt * r ^ 2 * efficiency
# index: 24 	column name:  total_renewable_policy_count
# index: 25 	column name:  Wind_policy_count
# index: 26 	column name:  Solar_photovoltaic_policy_count
